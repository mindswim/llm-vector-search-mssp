# %%
import yt_dlp

# %%
import time
import random
from requests.exceptions import RequestException

# %%
from utils.youtube_transcript_util import process_videos

# %%
def get_video_ids_from_playlist(playlist_url):
    ydl_opts = {'quiet': True, 'extract_flat': True}
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        result = ydl.extract_info(playlist_url, download=False)
        return [entry['id'] for entry in result['entries']]

# %%
playlist_url = "https://www.youtube.com/playlist?list=PLc_cXArusJxQcaMDG7CoG02kbyvQD1q78"

# %%
video_ids = get_video_ids_from_playlist(playlist_url)

# %%
video_ids
# Out:
# ['6SwTgS3sIoo',
#  'Pu-XzKAVjvs',
#  '18LFxJS8Mws',
#  'iswIFzrqf7E',
#  'EhX4EudjKLM',
#  'RxcpKDlPHdk',
#  'mdV1WGziOmA',
#  'KOVg-RcpcbE',
#  'pHjvPHmCBFI',
#  'QCuShQe745U',
#  'aRT4_4gQ5d8',
#  'mf0rY5ohIVg',
#  'hQK5gVwMW3s',
#  'iMJh21aXd0M',
#  'suHqxjhTiFQ',
#  'yeqvqSQMAqo',
#  'SbcfiRsRlZk',
#  'qnQJq_T-ZAk',
#  '712NMmRIz7I',
#  'NzCJxjNBddc',
#  'LkGtiJolnq0',
#  'lMA-tznT9V0',
#  'kH4ynPIefQk',
#  'RkMkrUV-3_c',
#  'DfHG5OzHkAE',
#  'EhSKxhghLqc',
#  '2zavTtY5ozI',
#  'jG0bIuSphwM',
#  'wSDABpRUulM',
#  'E7sEGVVB6JI',
#  'daQ3ewhnAc4',
#  '2ClPfZpZzmE',
#  'XUcF64-FhJk',
#  'busqj4BY9_M',
#  'PnmbMCtpLU8',
#  'fmTbNmMJodA',
#  'tIf1Yuq2Eeg',
#  'LM_ZKOX_QKg',
#  'jBawQsjjPFE',
#  '3iSZ_PvjLFo',
#  '7QbQtsgofT0',
#  'dW9RjmsKi28',
#  'yRhdBSqVa8Q',
#  '9ogkVhdVg3Q',
#  'iuOyJJAyzMI',
#  'Z4snC2tvATA',
#  'Lo8GqBGwIuk',
#  'Urdh5UexbA8',
#  'mMITs17FQjc',
#  'HS1sCk3w18w',
#  'xtI-OBsnlt0',
#  'HFoSdt1mncs',
#  'ywhumXRhvmw',
#  'TI8b2bgTvX0',
#  'VJ75YMnAMus',
# ...

# %%
#process_videos(video_ids)

# %%
import os

transcript_dir = 'yt-transcripts'
existing_video_ids = []

for filename in os.listdir(transcript_dir):
    if filename.startswith('transcript_') and filename.endswith('.txt'):
        video_id = filename[11:-4]  # Remove 'transcript_' and '.txt'
        existing_video_ids.append(video_id)

print(f"Found {len(existing_video_ids)} existing transcripts")
# Out:
# Found 324 existing transcripts

# %%
new_video_ids = [vid for vid in video_ids if vid not in existing_video_ids]

print(f"Found {len(new_video_ids)} new videos to process")
# Out:
# Found 600 new videos to process

# %%
process_videos(new_video_ids)
# Out:
# Saving transcripts to directory: yt-transcripts
# Processing video 1/600: EhX4EudjKLM
# ERROR: [youtube] EhX4EudjKLM: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
# Error processing video 1/600: EhX4EudjKLM
# Error message: ERROR: [youtube] EhX4EudjKLM: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
# Continuing to next video...
# ---
# Processing video 2/600: RxcpKDlPHdk
# ERROR: [youtube] RxcpKDlPHdk: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
# Error processing video 2/600: RxcpKDlPHdk
# Error message: ERROR: [youtube] RxcpKDlPHdk: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
# Continuing to next video...
# ---
# Processing video 3/600: pHjvPHmCBFI
# ERROR: [youtube] pHjvPHmCBFI: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
# Error processing video 3/600: pHjvPHmCBFI
# ...

# %%
import re

# Copy and paste the output from the process_videos function here
output_text = """
Saving transcripts to directory: yt-transcripts
Processing video 1/738: 18LFxJS8Mws
Saved transcript to: yt-transcripts/transcript_18LFxJS8Mws.txt
---
Processing video 2/738: EhX4EudjKLM
Error processing video 2/738: EhX4EudjKLM
Error message: 
Could not retrieve a transcript for the video https://www.youtube.com/watch?v=EhX4EudjKLM! This is most likely caused by:

Subtitles are disabled for this video

If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
Continuing to next video...
---
Processing video 3/738: RxcpKDlPHdk
Error processing video 3/738: RxcpKDlPHdk
Error message: 
Could not retrieve a transcript for the video https://www.youtube.com/watch?v=RxcpKDlPHdk! This is most likely caused by:

Subtitles are disabled for this video

If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
Continuing to next video...
---
Processing video 4/738: pHjvPHmCBFI
...
Processing video 74/738: OUaPeTUeppw
Saved transcript to: yt-transcripts/transcript_OUaPeTUeppw.txt
---
Processing video 75/738: MCstbEF2rpM
Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
ERROR: [youtube] MCstbEF2rpM: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
Error processing video 75/738: MCstbEF2rpM
Error message: ERROR: [youtube] MCstbEF2rpM: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
Continuing to next video...
---
Processing video 76/738: ZHmjvB4emYA
Saved transcript to: yt-transcripts/transcript_ZHmjvB4emYA.txt
---
Processing video 77/738: DJ5ExrfAncg
Saved transcript to: yt-transcripts/transcript_DJ5ExrfAncg.txt
---
Processing video 78/738: C5SofikD2KI
Saved transcript to: yt-transcripts/transcript_C5SofikD2KI.txt
---
Processing video 79/738: Yow71h8SN_I
Saved transcript to: yt-transcripts/transcript_Yow71h8SN_I.txt
---
Processing video 80/738: KkDfX8ti8n4
Saved transcript to: yt-transcripts/transcript_KkDfX8ti8n4.txt
---
Processing video 81/738: 0QvouM1jbfY
Saved transcript to: yt-transcripts/transcript_0QvouM1jbfY.txt
---
Processing video 82/738: kPyatXlGpkQ
Saved transcript to: yt-transcripts/transcript_kPyatXlGpkQ.txt
---
...
Processing video 95/738: _Ujwm7SvqPQ
Saved transcript to: yt-transcripts/transcript__Ujwm7SvqPQ.txt
---
Processing video 96/738: K0U_q1F-dn4
Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
ERROR: [youtube] K0U_q1F-dn4: This video has been removed for violating YouTube's Community Guidelines
Error processing video 96/738: K0U_q1F-dn4
Error message: ERROR: [youtube] K0U_q1F-dn4: This video has been removed for violating YouTube's Community Guidelines
Continuing to next video...
---
Processing video 97/738: H1zsAgko7EM
Saved transcript to: yt-transcripts/transcript_H1zsAgko7EM.txt
---
Processing video 98/738: 1tvYqt98pHc
Saved transcript to: yt-transcripts/transcript_1tvYqt98pHc.txt
---
Processing video 99/738: 3nnKxa8PDHY
Saved transcript to: yt-transcripts/transcript_3nnKxa8PDHY.txt
---
Processing video 100/738: lz5BtmrUng4
Saved transcript to: yt-transcripts/transcript_lz5BtmrUng4.txt
---
Processing video 101/738: gnO_gtWJNw0
Saved transcript to: yt-transcripts/transcript_gnO_gtWJNw0.txt
---
Processing video 102/738: 5rNWK-WSnUE
Saved transcript to: yt-transcripts/transcript_5rNWK-WSnUE.txt
---
Processing video 103/738: kfa9_aitC1E
Saved transcript to: yt-transcripts/transcript_kfa9_aitC1E.txt
---
...
Processing video 118/738: O97fkKSciVM
Saved transcript to: yt-transcripts/transcript_O97fkKSciVM.txt
---
Processing video 119/738: OhKdqciNjo8
Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
ERROR: [youtube] OhKdqciNjo8: This video has been removed for violating YouTube's Community Guidelines
Error processing video 119/738: OhKdqciNjo8
Error message: ERROR: [youtube] OhKdqciNjo8: This video has been removed for violating YouTube's Community Guidelines
Continuing to next video...
---
Processing video 120/738: LA-pULceG40
Saved transcript to: yt-transcripts/transcript_LA-pULceG40.txt
---
Processing video 121/738: fUTDMG_TGSc
Saved transcript to: yt-transcripts/transcript_fUTDMG_TGSc.txt
---
Processing video 122/738: G4aWB5-dTJs
Saved transcript to: yt-transcripts/transcript_G4aWB5-dTJs.txt
---
Processing video 123/738: etBgrMXt0ns
Error processing video 123/738: etBgrMXt0ns
Error message: 
Could not retrieve a transcript for the video https://www.youtube.com/watch?v=etBgrMXt0ns! This is most likely caused by:

Subtitles are disabled for this video

If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
Continuing to next video...
---
Processing video 124/738: 0KGriBtmfuA
Saved transcript to: yt-transcripts/transcript_0KGriBtmfuA.txt
...
If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
Continuing to next video...
---
Processing video 206/738: qf8wVXIpT6g
Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
ERROR: [youtube] qf8wVXIpT6g: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
Error processing video 206/738: qf8wVXIpT6g
Error message: ERROR: [youtube] qf8wVXIpT6g: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
Continuing to next video...
---
Processing video 207/738: PtGZVnSPOWU
Saved transcript to: yt-transcripts/transcript_PtGZVnSPOWU.txt
---
Processing video 208/738: QkqFJ5DqxhU
Saved transcript to: yt-transcripts/transcript_QkqFJ5DqxhU.txt
---
Processing video 209/738: wLeuqb38xzA
Error processing video 209/738: wLeuqb38xzA
Error message: 
Could not retrieve a transcript for the video https://www.youtube.com/watch?v=wLeuqb38xzA! This is most likely caused by:

Subtitles are disabled for this video

If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
Continuing to next video...
---
Processing video 210/738: RlNwbQzrxbk
Saved transcript to: yt-transcripts/transcript_RlNwbQzrxbk.txt
---
Processing video 211/738: 5TTWKz0blUo
Error processing video 211/738: 5TTWKz0blUo
...
Processing video 218/738: iMxfvnjyh1k
Saved transcript to: yt-transcripts/transcript_iMxfvnjyh1k.txt
---
Processing video 219/738: 9echx7QZRKQ
Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
ERROR: [youtube] 9echx7QZRKQ: Video unavailable. This video is no longer available due to a copyright claim by Salvador Williams
Error processing video 219/738: 9echx7QZRKQ
Error message: ERROR: [youtube] 9echx7QZRKQ: Video unavailable. This video is no longer available due to a copyright claim by Salvador Williams
Continuing to next video...
---
Processing video 220/738: aj-YuLJnd-A
ERROR: [youtube] aj-YuLJnd-A: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
Error processing video 220/738: aj-YuLJnd-A
Error message: ERROR: [youtube] aj-YuLJnd-A: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
Continuing to next video...
---
Processing video 221/738: wnly8bR8UAo
ERROR: [youtube] wnly8bR8UAo: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
Error processing video 221/738: wnly8bR8UAo
Error message: ERROR: [youtube] wnly8bR8UAo: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
Continuing to next video...
---
Processing video
Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
Continuing to next video...
---
Processing video 241/738: P189u86uBNw
Saved transcript to: yt-transcripts/transcript_P189u86uBNw.txt
---
Processing video 242/738: 3_sue6lLPF0
Saved transcript to: yt-transcripts/transcript_3_sue6lLPF0.txt
---
Processing video 243/738: ohjpAZr1OII
Saved transcript to: yt-transcripts/transcript_ohjpAZr1OII.txt
---
Processing video 244/738: 7KiTUB5hd44
Saved transcript to: yt-transcripts/transcript_7KiTUB5hd44.txt
---
Processing video 245/738: 6nk6c3Ey85E
Saved transcript to: yt-transcripts/transcript_6nk6c3Ey85E.txt
---
Processing video 246/738: Una53bz9tgc
Saved transcript to: yt-transcripts/transcript_Una53bz9tgc.txt
---
Processing video 247/738: cQwFclhb10I
Saved transcript to: yt-transcripts/transcript_cQwFclhb10I.txt
---
...
If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
Continuing to next video...
---
Processing video 255/738: wlJfVWPRQ4g
Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
ERROR: [youtube] wlJfVWPRQ4g: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Error processing video 255/738: wlJfVWPRQ4g
Error message: ERROR: [youtube] wlJfVWPRQ4g: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Continuing to next video...
---
Processing video 256/738: x2xXDDUFc8g
ERROR: [youtube] x2xXDDUFc8g: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Error processing video 256/738: x2xXDDUFc8g
Error message: ERROR: [youtube] x2xXDDUFc8g: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Continuing to next video...
---
Processing video 257/738: 6O94BxngpWM
ERROR: [youtube] 6O94BxngpWM: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Error processing video 257/738: 6O94BxngpWM
Error message: ERROR: [youtube] 6O94BxngpWM: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Continuing to next video...
---
Processing video 258/738: vyr0_J8VB9g
ERROR: [youtube] vyr0_J8VB9g: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Error processing video 258/738: vyr0_J8VB9g
Error message: ERROR: [youtube] vyr0_J8VB9g: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Continuing to next video...
---
Processing video 259/738: PX3PWQCSBcA
Error processing video 259/738: PX3PWQCSBcA
Error message: 
Could not retrieve a transcript for the video https://www.youtube.com/watch?v=PX3PWQCSBcA! This is most likely caused by:

Subtitles are disabled for this video

If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
Continuing to next video...
---
Processing video 260/738: qWXX9S9E75U
ERROR: [youtube] qWXX9S9E75U: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Error processing video 260/738: qWXX9S9E75U
Error message: ERROR: [youtube] qWXX9S9E75U: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Continuing to next video...
---
Processing video 261/738: uBoOJgknbDY
ERROR: [youtube] uBoOJgknbDY: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Error processing video 261/738: uBoOJgknbDY
Error message: ERROR: [youtube] uBoOJgknbDY: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Continuing to next video...
---
Processing video 262/738: eilfPnGBLso
ERROR: [youtube] eilfPnGBLso: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Error processing video 262/738: eilfPnGBLso
Error message: ERROR: [youtube] eilfPnGBLso: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Continuing to next video...
---
Processing video 263/738: JZPEQ6hoMas
ERROR: [youtube] JZPEQ6hoMas: Private video. Sign in if you've been granted access to this video
Error processing video 263/738: JZPEQ6hoMas
Error message: ERROR: [youtube] JZPEQ6hoMas: Private video. Sign in if you've been granted access to this video
Continuing to next video...
---
Processing video 264/738: 8PU7ECkxvio
ERROR: [youtube] 8PU7ECkxvio: Private video. Sign in if you've been granted access to this video
Error processing video 264/738: 8PU7ECkxvio
Error message: ERROR: [youtube] 8PU7ECkxvio: Private video. Sign in if you've been granted access to this video
Continuing to next video...
---
Processing video 265/738: PRFGe7eSX_U
Error processing video 265/738: PRFGe7eSX_U
Error message: 
Could not retrieve a transcript for the video https://www.youtube.com/watch?v=PRFGe7eSX_U! This is most likely caused by:

Subtitles are disabled for this video

If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
Continuing to next video...
---
Processing video 266/738: G94eBB9GRWM
ERROR: [youtube] G94eBB9GRWM: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Error processing video 266/738: G94eBB9GRWM
Error message: ERROR: [youtube] G94eBB9GRWM: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Continuing to next video...
---
Processing video
Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Error processing video 283/738: F5jA9saaWBg
Error message: ERROR: [youtube] F5jA9saaWBg: Sign in to confirm you’re not a bot. This helps protect our community. Learn more
Continuing to next video...
---
Processing video 284/738: NGA9mrohJMg
ERROR: [youtube] NGA9mrohJMg: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
Error processing video 284/738: NGA9mrohJMg
Error message: ERROR: [youtube] NGA9mrohJMg: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
Continuing to next video...
---
Processing video 285/738: kiF6iXV5pn4
ERROR: [youtube] kiF6iXV5pn4: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
Error processing video 285/738: kiF6iXV5pn4
Error message: ERROR: [youtube] kiF6iXV5pn4: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
Continuing to next video...
---
Processing video 286/738: sKkKMrtMGX8
ERROR: [youtube] sKkKMrtMGX8: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
Error processing video 286/738: sKkKMrtMGX8
Error message: ERROR: [youtube] sKkKMrtMGX8: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
Continuing to next video...
---
Processing video 287/738: E-Nntq_uUyM
"""

# %%
error_video_ids = re.findall(r"ERROR: \[youtube\] (\w+):", output_text)
print("Error video IDs:", error_video_ids)

# Remove error videos from new_video_ids
new_video_ids = [vid for vid in new_video_ids if vid not in error_video_ids]

print(f"Remaining videos to process: {len(new_video_ids)}")
# Out:
# Error video IDs: ['MCstbEF2rpM', 'MCstbEF2rpM', 'OhKdqciNjo8', 'OhKdqciNjo8', 'qf8wVXIpT6g', 'qf8wVXIpT6g', '9echx7QZRKQ', '9echx7QZRKQ', 'wnly8bR8UAo', 'wnly8bR8UAo', 'PK83yWPDnms', 'PK83yWPDnms', '9vtt1WbvsGk', '9vtt1WbvsGk', 'LEKNUjN0Mws', 'LEKNUjN0Mws', 'VFFAe_rNez0', 'VFFAe_rNez0', 'fh5pfaO6Xcg', 'fh5pfaO6Xcg', '54nGLiOUud8', '54nGLiOUud8', '9X2QTKA4vAg', '9X2QTKA4vAg', 'GXO_8bXlMa8', 'GXO_8bXlMa8', 'Odewit6KAQE', 'Odewit6KAQE', 'XU1QWrDYbnU', 'XU1QWrDYbnU', 'pQXWQbQa5jU', 'pQXWQbQa5jU', 'R6y2gIAtr4E', 'R6y2gIAtr4E', 'wlJfVWPRQ4g', 'wlJfVWPRQ4g', 'x2xXDDUFc8g', 'x2xXDDUFc8g', '6O94BxngpWM', '6O94BxngpWM', 'vyr0_J8VB9g', 'vyr0_J8VB9g', 'qWXX9S9E75U', 'qWXX9S9E75U', 'uBoOJgknbDY', 'uBoOJgknbDY', 'eilfPnGBLso', 'eilfPnGBLso', 'JZPEQ6hoMas', 'JZPEQ6hoMas', '8PU7ECkxvio', '8PU7ECkxvio', 'G94eBB9GRWM', 'G94eBB9GRWM', 'qF2LnGxQfVA', 'qF2LnGxQfVA', '9sMqtO8GyWw', '9sMqtO8GyWw', 'WTfheerrEtY', 'WTfheerrEtY', '352AVukm1qw', '352AVukm1qw', 'wxOPplxC1BM', 'wxOPplxC1BM', 'BikuwjfbyhE', 'Biku
# ...

# %%
process_videos(video_ids, cookies='youtube_cookies.txt')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 process_videos(video_ids, cookies='youtube_cookies.txt')
#
# TypeError: process_videos() got an unexpected keyword argument 'cookies'
